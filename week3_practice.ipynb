# %%
import nltk
from nltk.corpus import *
from nltk import *
from matplotlib.pylab import *
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 10.0)
plt.rcParams.update({'font.size': 10})

# %%
cndList = [(word.lower(),fileName) for fileName in inaugural.fileids() for word in inaugural.words(fileids = fileName)]
ConditionalFreqDist(cndList).plot(conditions = ["men","women","people"])

# %%
from nltk.corpus import wordnet as wn

# %%
wn.synset('tree.n.01').member_meronyms()
# Out:
# []

# %%
wn.synset('tree.n.01').part_meronyms()
# Out:
# [Synset('burl.n.02'),
#  Synset('crown.n.07'),
#  Synset('limb.n.02'),
#  Synset('stump.n.01'),
#  Synset('trunk.n.01')]

# %%
wn.synset('tree.n.01').substance_meronyms()
# Out:
# [Synset('heartwood.n.01'), Synset('sapwood.n.01')]

# %%
wn.synset('tree.n.01').member_holonyms()
# Out:
# [Synset('forest.n.01')]

# %%
wn.synset('tree.n.01').part_holonyms()
# Out:
# []

# %%
wn.synset('tree.n.01').substance_holonyms()
# Out:
# []

# %%
word = nltk.corpus.words.words()

# %%
names = nltk.corpus.names

# %%
pair = [(gender,word[:1]) for gender in names.fileids() for word in names.words(fileids =  gender)]

# %%
ConditionalFreqDist(pair).plot()

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text2.
# Out:
# FreqDist({'[': 3,
#           'Sense': 1,
#           'and': 3350,
#           'Sensibility': 1,
#           'by': 737,
#           'Jane': 1,
#           'Austen': 1,
#           '1811': 1,
#           ']': 1,
#           'CHAPTER': 50,
#           '1': 2,
#           'The': 243,
#           'family': 83,
#           'of': 3565,
#           'Dashwood': 252,
#           'had': 969,
#           'long': 100,
#           'been': 440,
#           'settled': 37,
#           'in': 1904,
#           'Sussex': 9,
#           '.': 3975,
#           'Their': 33,
#           'estate': 19,
#           'was': 1846,
#           'large': 26,
#           ',': 9397,
#           'their': 463,
#           'residence': 7,
#           'at': 806,
#           'Norland': 53,
#           'Park': 22,
#           'the': 3861,
#           'centre': 2,
#           'property': 9,
#           'where': 84,
#           'for': 1234,
#           'many': 98,
#           'generations': 1,
#           'they': 428,
# ...

# %%
dict = nltk.corpus.cmudict.dict()

# %%
text2.similar('monstrous')
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
text2.similar('passing')
# Out:
# long in at for but all not added on only tied considerable there still
# enough led exactly equally possible considered

# %%
modal_words = ['can','could','may','might','must','will']
cndList = [(genre,word.lower()) for genre in brown.categories() for word in brown.words(categories=genre)]
ConditionalFreqDist(cndList).plot(samples = modal_words)

# %%
len(set([w[0] for w in nltk.corpus.cmudict.entries()]))
# Out:
# 123455

# %%
wn.all_synsets('n')
# Out:
# <generator object WordNetCorpusReader.all_synsets at 0x0000015D662CE2B0>
