# %% [markdown]
# 1.☼ Search the web for "spoof newspaper headlines", to find such gems as: British Left Waffles on Falkland Islands, and Juvenile Court to Try Shooting Defendant. Manually tag these headlines to see if knowledge of the part-of-speech tags removes the ambiguity.
#
# **ans** Drunk Gets Nine Months in Violin Case
# [(Drunk,NOUN),(Gets,VERB),(Nine,NOUN),(Months,NOUN),(in,PREP),(Violin,NOUN),(Violin,case)]

# %% [markdown]
# 14.◑ Use sorted() and set() to get a sorted list of tags used in the Brown corpus, removing duplicates.

# %%
from nltk.corpus import brown
tags = brown.tagged_words()
print(sorted(set([tag[1] for tag in tags])))
# Out:
# ["'", "''", '(', '(-HL', ')', ')-HL', '*', '*-HL', '*-NC', '*-TL', ',', ',-HL', ',-NC', ',-TL', '--', '---HL', '.', '.-HL', '.-NC', '.-TL', ':', ':-HL', ':-TL', 'ABL', 'ABN', 'ABN-HL', 'ABN-NC', 'ABN-TL', 'ABX', 'AP', 'AP$', 'AP+AP-NC', 'AP-HL', 'AP-NC', 'AP-TL', 'AT', 'AT-HL', 'AT-NC', 'AT-TL', 'AT-TL-HL', 'BE', 'BE-HL', 'BE-TL', 'BED', 'BED*', 'BED-NC', 'BEDZ', 'BEDZ*', 'BEDZ-HL', 'BEDZ-NC', 'BEG', 'BEM', 'BEM*', 'BEM-NC', 'BEN', 'BEN-TL', 'BER', 'BER*', 'BER*-NC', 'BER-HL', 'BER-NC', 'BER-TL', 'BEZ', 'BEZ*', 'BEZ-HL', 'BEZ-NC', 'BEZ-TL', 'CC', 'CC-HL', 'CC-NC', 'CC-TL', 'CC-TL-HL', 'CD', 'CD$', 'CD-HL', 'CD-NC', 'CD-TL', 'CD-TL-HL', 'CS', 'CS-HL', 'CS-NC', 'CS-TL', 'DO', 'DO*', 'DO*-HL', 'DO+PPSS', 'DO-HL', 'DO-NC', 'DO-TL', 'DOD', 'DOD*', 'DOD*-TL', 'DOD-NC', 'DOZ', 'DOZ*', 'DOZ*-TL', 'DOZ-HL', 'DOZ-TL', 'DT', 'DT$', 'DT+BEZ', 'DT+BEZ-NC', 'DT+MD', 'DT-HL', 'DT-NC', 'DT-TL', 'DTI', 'DTI-HL', 'DTI-TL', 'DTS', 'DTS+BEZ', 'DTS-HL', 'DTX', 'EX', 'EX+BEZ', 'EX+HVD', 'EX+HVZ', 'EX+MD', 'EX-HL', 'EX-NC', 'FW-*', 'FW-*-TL', 'FW-AT', 'FW-AT+NN-TL', 'FW-AT+NP-TL', 'FW-AT-HL', 'FW-AT-TL', 'FW-BE', 'FW-BER', 'FW-BEZ', 'FW-CC', 'FW-CC-TL', 'FW-CD', 'FW-CD-TL', 'FW-CS', 'FW-DT', 'FW-DT+BEZ', 'FW-DTS', 'FW-HV', 'FW-IN', 'FW-IN+AT', 'FW-IN+AT-T', 'FW-IN+AT-TL', 'FW-IN+NN', 'FW-IN+NN-TL', 'FW-IN+NP-TL', 'FW-IN-TL', 'FW-JJ', 'FW-JJ-NC', 'FW-JJ-TL', 'FW-JJR', 'FW-JJT', 'FW-NN', 'FW-NN$', 'FW-NN$-TL', 'FW-NN-NC', 'FW-NN-TL', 'FW-NN-TL-NC', 'FW-NNS', 'FW-NNS-NC', 'FW-NNS-TL', 'FW-NP', 'FW-NP-TL', 'FW-NPS', 'FW-NPS-TL', 'FW-NR',
+BER-NC', 'PPSS+BER-TL', 'PPSS+BEZ', 'PPSS+BEZ*', 'PPSS+HV', 'PPSS+HV-TL', 'PPSS+HVD', 'PPSS+MD', 'PPSS+MD-NC', 'PPSS+VB', 'PPSS-HL', 'PPSS-NC', 'PPSS-TL', 'QL', 'QL-HL', 'QL-NC', 'QL-TL', 'QLP', 'RB', 'RB$', 'RB+BEZ', 'RB+BEZ-HL', 'RB+BEZ-NC', 'RB+CS', 'RB-HL', 'RB-NC', 'RB-TL', 'RBR', 'RBR+CS', 'RBR-NC', 'RBT', 'RN', 'RP', 'RP+IN', 'RP-HL', 'RP-NC', 'RP-TL', 'TO', 'TO+VB', 'TO-HL', 'TO-NC', 'TO-TL', 'UH', 'UH-HL', 'UH-NC', 'UH-TL', 'VB', 'VB+AT', 'VB+IN', 'VB+JJ-NC', 'VB+PPO', 'VB+RP', 'VB+TO', 'VB+VB-NC', 'VB-HL', 'VB-NC', 'VB-TL', 'VBD', 'VBD-HL', 'VBD-NC', 'VBD-TL', 'VBG', 'VBG+TO', 'VBG-HL', 'VBG-NC', 'VBG-TL', 'VBN' ...

# %% [markdown]
# 15.◑ Write programs to process the Brown Corpus and find answers to the following questions:

# %% [markdown]
# 15.1 Which nouns are more common in their plural form, rather than their singular form? (Only consider regular plurals, formed with the -s suffix.)

# %%
from nltk.corpus import brown
from nltk import FreqDist

noun_list = [word.lower() for word,tag in brown.tagged_words(tagset='universal') if tag == "NOUN"]
noun_plurals = [word for word in noun_list if word.endswith("s")]
noun_singula =  [word for word in noun_list if not word.endswith("s")]
freq_plurals = FreqDist(noun_plurals)
freq_singular = FreqDist(noun_singula)
result = [word for word in freq_plurals.keys() if freq_plurals[word] > freq_singular[word[:-1]]]
print(result)
#answer display below
# Out:
# ["atlanta's", 'irregularities', 'presentments', 'thanks', 'voters', "georgia's", 'legislators', 'topics', 'policies', 'steps', 'funds', "department's", 'items', 'counties', 'taxpayers', "ordinary's", 'appraisers', 'fees', 'juries', 'citizens', "court's", 'servants', 'concessionaires', 'deputies', 'officials', 'employes', "commissioner's", "mayor's", "wife's", "governor's", 'snodgrass', 'james', 'texas', 'candidates', 'relations', "byrd's", "caldwell's", 'years', 'bonds', 'sales', 'authorities', "body's", 'allowances', 'members', 'congress', 'davis', "saturday's", 'polls', "daniel's", 'bankers', 'rules', 'witnesses', 'dollars', 'means', 'companies', 'obligations', 'depositors', 'customers', 'millions', 'charles', 'hughes', 'jones', 'dallas', 'students', 'harris', 'savings', "year's", 'scholastics', 'parimutuels', "berry's", 'ponies', 'cities', 'louis', 'retailers', 'taxes', 'correctness', 'series', 'paris', 'brokers', 'gas', 'vacancies', "formby's", 'representatives', 'texans', 'affairs', 'two-thirds', 'majorities', "cotten's", "bill's", 'defenders', 'dumas', 'collins', "boy's", 'hours', "master's", 'physics', 'co-signers', 'regents', "school's", 'massachusetts', 'corps', 'relatives', 'parents', 'defendants', 'parsons', 'bellows', 'observers', 'clements', 'aspects', 'others', 'business', 'crisis', 'address', 'hyannis', 'press', 'advisers', "russia's", 'karns', 'proceedings', 'morris', 'subpoenas', 'subpenas', 'processes', 'process', 'workers', 'americans', 'illness', 'excess', 'requirements', "president's", "nation's", "children's", 'facilities', 'elements', 'ayes', 'noes', "eisenhower's", "kennedy's", 'difficulties', 'tragedies', 'allies', 'circumstances', 'critics', 'manifestations', 'arms', "rusk's", 'speeches', 'analysis', 'vagueness', 'events', 'months', 'submarines', "nato's", "secretary's", 'societies', 'impetus', 'countries', "alliance's", 'laos', 'modifications', 'errors', 'politics', 'brandeis', 'conditions', 'victories', 'channels', 'negotiations', 'emphasis', 'nations', 'losses', 'neighbors', 'arkansas', 'communities', "state's", 'basis', 'residents', 'headquarters', 'sirens', 'status', 'intervals', 'things', 'classes', 'revisions', 'miss', "nugent's", 'supermarkets', "council's", 'thousands', 'liberals', 'conservatives', 'parties', 'utilities', 'resources', 'manufacturers', 'canvassers', 'awareness', "town's", 'signers', 'motorists', "monday's", 'carcass', 'plains', 'chorus', 'boos', "women's", 'remains', 'closeness', "fall's", 'surplus', 'joblessness', 'minutes', 'barbs', 'crises', 'vehicles', 'leaders', "party's", "jersey's", "case's", 'roos', "organization's", 'techniques', 'cross', 'democrats', '1940s', "meyner's", 'acres', 'municipalities', 'colleagues', 'terms', 'elephants', 'tusks', '1920s', 'weakness', "leader's", "gerosa's", 'reporters', 'feis', 'campus', "yesterday's", 'politicians', "o'connor's", 'forecasts', "administration's", "panel's", "rayburn's", 'down-payments', 'families', 'dormitories', 'thomas', 'progress', 'mathematics', 'agencies', 'universities', 'overseas', 'technicians', 'experts', "country's", 'inhabitants', 'diplomats', 'tactics', "france's", "canada's", 'princess', "phouma's", 'laotians', 'factors', 'orleans', 'miles', 'hundreds', 'ceremonies', "government's", 'suffragettes', 'soldiers', 'archives', 'spectators', 'branches', 'academies', 'territories', 'ross', 'friends', 'job-seekers', 'commitments', 'lawmakers', 'odds', 'eyes', "mississippi's", 'crossroads', 'independents', 'stennis', 'stresses', 'tardiness', 'effectiveness', 'inconsistencies', 'allegations', 'followers', 'affiliations', "city's", 'loss', 'shortcuts', "controller's", 'disclosures', 'vouchers', 'industries', "berger's", 'douglas', 'goodis', 'accomodations', 'owners', 'bites', 'gillis', "barnard's", 'hess', 'redevelopers', "authority's", 'churches', 'reynolds', 'doxiadis', 'walkways', 'kansas', 'fighters', 'teamsters', "gladden's", "car's", "union's", "association's", 'menderes', 'products', "portland's", 'mears', 'barne ...

# %% [markdown]
# 15.2 Which word has the greatest number of distinct tags. What are they, and what do they represent?

# %%
from nltk import ConditionalFreqDist
from nltk.corpus import brown

freq2D = ConditionalFreqDist(brown.tagged_words(tagset='universal'))
sortedDist = sorted([(name,len(freq2D[name])) for name in freq2D.keys()], key=lambda x: x[1],reverse=True)
print(sortedDist[0][0])
print(freq2D[sortedDist[0][0]].keys())

#answer below
#word has the greatest number of distinct tags: that
#What are they: ['ADP', 'PRON', 'DET', 'ADV', 'X']
#what do they represent: that have many difference meaning
# Out:
# that
# dict_keys(['ADP', 'PRON', 'DET', 'ADV', 'X'])

# %% [markdown]
# 15.3 List tags in order of decreasing frequency. What do the 20 most frequent tags represent?

# %%
from nltk.corpus import brown
from nltk import FreqDist

print(FreqDist([tag for word,tag in brown.tagged_words()]).most_common(20))
#Answer below
# Out:
# [('NN', 152470), ('IN', 120557), ('AT', 97959), ('JJ', 64028), ('.', 60638), (',', 58156), ('NNS', 55110), ('CC', 37718), ('RB', 36464), ('NP', 34476), ('VB', 33693), ('VBN', 29186), ('VBD', 26167), ('CS', 22143), ('PPS', 18253), ('VBG', 17893), ('PP$', 16872), ('TO', 14918), ('PPSS', 13802), ('CD', 13510)]

# %% [markdown]
# 15.4 Which tags are nouns most commonly found after? What do these tags represent?

# %%
from nltk.corpus import brown
from nltk import FreqDist,bigrams

brown_news_tagged = brown.tagged_words(tagset = 'universal')
word_tag_pairs = list(bigrams(brown_news_tagged))
noun_preceders = [b[1] for (a,b) in word_tag_pairs if a[1] == 'NOUN'] 
fdist = FreqDist(noun_preceders)
print(fdist.most_common(1)[0])
#Answer below
#most commonly found: .
#What do these tags represent: i don't known, "." isn't describe in upenn tagset (https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html)
# Out:
# ('.', 78326)

# %% [markdown]
# 18.◑ Generate some statistics for tagged data to answer the following questions:

# %% [markdown]
# 18.1 What proportion of word types are always assigned the same part-of-speech tag

# %%
from nltk.corpus import brown
from nltk import ConditionalFreqDist
brown_news_tagged = brown.tagged_words(tagset = 'universal')
confreq = ConditionalFreqDist([(word.lower(),tag)for word,tag in brown_news_tagged])
single_tag = len([1 for word in confreq.conditions() if len(confreq[word]) == 1])
set_len = len(set([word.lower() for word,tag in brown_news_tagged]))
print(single_tag/set_len)
#Answer below
# Out:
# 0.9315868714242698

# %% [markdown]
# 18.2 How many words are ambiguous, in the sense that they appear with at least two tags?

# %%
from nltk.corpus import brown
from nltk import ConditionalFreqDist
freq2D = ConditionalFreqDist(brown.tagged_words(tagset='universal'))
ambiguous = [(name,len(freq2D[name])) for name in freq2D.keys() if len(freq2D[name]) >= 2]
print("ambiguous", len(ambiguous))
#Answer below
# Out:
# ambiguous 3596

# %% [markdown]
# 18.3 What percentage of word tokens in the Brown Corpus involve these ambiguous words?

# %%
from nltk.corpus import brown
from nltk import ConditionalFreqDist
wordlist = brown.tagged_words(tagset='universal')
freq2D = ConditionalFreqDist(wordlist)
ambiguous_set = set([name for name in freq2D.keys() if len(freq2D[name]) >= 2])
tokenlist =  [1 for word,tag in wordlist if word in ambiguous_set]
print(len(tokenlist)/len(wordlist)*100,'%')
#Answer below
# Out:
# 52.81503833991278 %

# %% [markdown]
# 20.Write code to search the Brown Corpus for particular words and phrases according to tags, to answer the following questions:

# %% [markdown]
# 20.1 Produce an alphabetically sorted list of the distinct words tagged as MD.

# %%
from nltk.corpus import brown
from nltk import ConditionalFreqDist

cfd = ConditionalFreqDist(brown.tagged_words())
md_words = [word for word in cfd.conditions() if cfd[word]['MD'] != 0]
print(md_words)
# Out:
# ['should', 'may', 'might', 'will', 'would', 'must', 'can', 'need', 'could', 'Must', 'Should', 'May', 'shall', 'Can', 'Could', 'Would', 'ought', 'Will', 'Ought', 'dare', 'wilt', 'Shall', 'mayst', 'wold', 'wod', 'Might', 'kin', 'wil', 'mai', 'maye', 'colde', 'shuld', 'shulde', 'wolde', "c'n", 'maht']

# %% [markdown]
# 20.2 Identify words that can be plural nouns or third person singular verbs (e.g. deals, flies).

# %%
from nltk.corpus import brown
from nltk import ConditionalFreqDist

cfd = ConditionalFreqDist(brown.tagged_words())
two_words = [condition for condition in conditions if cfd[condition]['NNS'] and cfd[condition]['VBZ']]
print(two_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-36c0b8958c8c> in <module>()
#       3
#       4 cfd = ConditionalFreqDist(brown.tagged_words())
# ----> 5 two_words = [condition for condition in conditions if cfd[condition]['NNS'] and cfd[condition]['VBZ']]
#       6 print(two_words)
#
# NameError: name 'conditions' is not defined
